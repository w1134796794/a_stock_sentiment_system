# %%
import tushare as ts
pro = ts.pro_api('9cb1d6a7b3a5cabf27023a45b0996e1f8e0c1e2676228278aed56cc7')
# df = pro.limit_list_d(trade_date='20260323', limit_type='U')
df = pro.limit_cpt_list( trade_date='20260417')
df
# Out:
#       ts_code        name trade_date  days up_stat cons_nums  up_nums  \
# 0   885756.TI        芯片概念   20260417     1    7天4板         5       26
# 1   885806.TI        华为概念   20260417    15   13天9板         7       25
# 2   885431.TI       新能源汽车   20260417    10    5天3板         2       19
# 3   885800.TI      消费电子概念   20260417     1    7天4板         5       17
# 4   885556.TI          5G   20260417     1   13天9板         3       16
# 5   885921.TI          储能   20260417     2    7天7板         5       16
# 6   886033.TI  共封装光学(CPO)   20260417     1    7天4板         3       14
# 7   885531.TI        光伏概念   20260417     2    5天3板         2       14
# 8   885517.TI       机器人概念   20260417     5    4天4板         2       14
# 9   885710.TI       锂电池概念   20260417     6    7天7板         5       13
# 10  886044.TI       液冷服务器   20260417     1    7天7板         3       12
# 11  885929.TI        专精特新   20260417     2    2天2板         3       12
# 12  885997.TI       比亚迪概念   20260417     1      首板         0       12
# 13  886078.TI        商业航天   20260417     1    5天5板         2       11
# 14  885545.TI        汽车电子   20260417     1    7天4板         1       11
# 15  885700.TI          军工   20260417     7    7天7板         5       11
# 16  885887.TI        数据中心   20260417     2    7天7板         2       11
# 17  886009.TI        先进封装   20260417     1    7天4板         1       10
# 18  885959.TI       PCB概念   20260417     1      首板         0       10
# 19  885738.TI        OLED   20260417     1    7天4板         3       10
#
#     pct_chg  rank
# 0    1.7576     1
# 1    0.7282     2
# 2    0.9860     3
# 3    1.6404     4
# 4    1.4889     5
# 5    0.6935     6
# 6    3.7581     7
# 7    1.0922     8
# 8    0.7057     9
# 9    1.1861    10
# 10   1.4190    11
# 11   1.3176    12
# 12   1.1386    13
# 13   1.3566    14
# 14   1.3340    15
# 15   1.1576    16
# 16   0.6735    17
# 17   2.9098    18
# 18   2.8028    19
# 19   1.9251    20

# %%
import akshare as ak

stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20260403", end_date='20260403', adjust="qfq")
print(stock_zh_a_hist_df)
# Out:
#            日期    股票代码     开盘     收盘     最高     最低     成交量           成交额    振幅  \
# 0  2026-04-03  000001  11.28  11.12  11.28  11.09  757757  8.452836e+08  1.69
#
#     涨跌幅   涨跌额   换手率
# 0 -1.33 -0.15  0.39

# %%
df = pro.dc_index(idx_type = '行业板块',trade_date = '20260324')
df.sort_values(by = 'pct_change',inplace = True)
df

# %%
import akshare as ak

df = ak.stock_zt_pool_em('20260323')
df
