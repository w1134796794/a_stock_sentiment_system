# %%
import tushare as ts
import os

token = os.getenv('TUSHARE_TOKEN')
pro = ts.pro_api(token=token)
# df = pro.limit_list_d(trade_date='20260323', limit_type='U')

df = pro.limit_list_d(trade_date='20260624',limit_type='D')
df
# Out:
# 9cb1d6a7b3a5cabf27023a45b0996e1f8e0c1e2676228278aed56cc7
#    trade_date    ts_code industry  name  close  pct_chg        amount  \
# 0    20260624  000004.SZ     软件开发   国华退   0.28    -9.68  1.223371e+06
# 1    20260624  000029.SZ    房地产开发  深深房Ａ  26.15    -9.98  1.424325e+08
# 2    20260624  000151.SZ      贸易Ⅱ  中成股份  11.95   -10.02  2.472471e+08
# 3    20260624  002535.SZ     专用设备  林州重机   2.22   -10.12  6.015632e+07
# 4    20260624  002808.SZ     光学光电   恒久退   0.18   -10.00  6.610070e+06
# 5    20260624  600598.SH      种植业   北大荒  11.22   -10.02  6.896752e+08
# 6    20260624  600977.SH     影视院线  中国电影  13.59   -10.00  1.350770e+09
# 7    20260624  603159.SH     专用设备  上海亚虹  21.06   -10.00  5.511402e+06
# 8    20260624  603201.SH    汽车零部件  常润股份  19.22    -9.98  7.530655e+07
# 9    20260624  603318.SH      燃气Ⅱ  水发燃气  10.52   -10.01  3.870407e+08
# 10   20260624  605303.SH     基础建设  园林股份  25.31    -9.99  2.553020e+07
# 11   20260624  605566.SH     化学制品  福莱蒽特  43.81   -10.00  3.932548e+08
#
#     limit_amount      float_mv      total_mv  turnover_ratio    fd_amount  \
# 0   2.985484e+06  3.536094e+07  3.706648e+07            3.42    1383961.0
# 1   3.454703e+08  2.331691e+10  2.645491e+10            0.61   46575555.0
# 2   3.119906e+07  3.679820e+09  4.193330e+09            6.52    1662245.0
# 3   1.817978e+07  1.656783e+09  1.779736e+09            3.51    3503781.0
# 4   4.803533e+06  3.363499e+07  4.838400e+07           19.39      46221.0
# 5   6.059210e+09  1.994557e+10  1.994557e+10            3.45   60353524.0
# 6   2.227286e+08  2.537253e+10  2.537253e+10            5.21   42664446.0
# 7   3.098832e+08  2.948400e+09  2.948400e+09            0.19   82600268.0
# 8   4.122498e+07  3.620178e+09  3.651410e+09            2.06   58320014.0
# 9   1.483578e+08  4.829426e+09  5.835162e+09            7.93  136949212.0
# 10  4.902446e+08  4.080919e+09  4.080919e+09            0.63   61138836.0
# 11  8.299366e+07  5.841625e+09  5.841625e+09            6.55   20098713.0
#
#    first_time last_time  open_times up_stat  limit_times limit
# 0        None     93103           0    None            1     D
# 1        None    100603           2    None            1     D
# 2        None    141503           6    None            1     D
# 3        None    134615          23    None            1     D
# 4        None    145003           1    None            1     D
# 5        None     94322           0    None            2     D
# 6        None    130033           8    None            1     D
# 7        None     92503           0    None            2     D
# 8        None     93515           3    None            1     D
# 9        None     94052           1    None            1     D
# 10       None     92504           0    None            2     D
# 11       None    135618           3    None            1     D

# %%
import akshare as ak

stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20260403", end_date='20260403', adjust="qfq")
print(stock_zh_a_hist_df)
# Out:
#            日期    股票代码     开盘     收盘     最高     最低     成交量           成交额    振幅  \
# 0  2026-04-03  000001  11.28  11.12  11.28  11.09  757757  8.452836e+08  1.69
#
#     涨跌幅   涨跌额   换手率
# 0 -1.33 -0.15  0.39

# %%
df = pro.dc_index(idx_type = '行业板块',trade_date = '20260324')
df.sort_values(by = 'pct_change',inplace = True)
df

# %%
import akshare as ak

df = ak.stock_zt_pool_em('20260323')
df
