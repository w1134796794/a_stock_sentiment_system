# %%
import tushare as ts
pro = ts.pro_api('9cb1d6a7b3a5cabf27023a45b0996e1f8e0c1e2676228278aed56cc7')
# df = pro.limit_list_d(trade_date='20260323', limit_type='U')

df = pro.daily(ts_code='603272.SH',trade_date='20260427')
df
# Out:
#      ts_code trade_date  open  high   low  close  pre_close  change  pct_chg  \
# 0  603272.SH   20260427  24.3  24.3  23.2   24.3      22.09    2.21  10.0045
#
#        vol      amount
# 0  59286.0  143174.844

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: partially initialized module 'pandas' from 'g:\a_stock_sentiment_system\.venv\Lib\site-packages\pandas\__init__.py' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import tushare as ts
#       2 pro = ts.pro_api('9cb1d6a7b3a5cabf27023a45b0996e1f8e0c1e2676228278aed56cc7')
#       3 # df = pro.limit_list_d(trade_date='20260323', limit_type='U')
#
# File g:\a_stock_sentiment_system\.venv\Lib\site-packages\tushare\__init__.py:11
#       6 __author__ = 'Jimmy Liu'
#       8 """
#       9 for trading data
#      10 """
# ---> 11 from tushare.stock.trading import (get_hist_data, get_tick_data,
#      12                                    get_today_all, get_realtime_quotes,
#      13                                    get_h_data, get_today_ticks,
#      14                                    get_index, get_hists,
#      15                                    get_k_data, get_day_all,
#      16                                    get_sina_dd, bar, tick,
#      17                                    get_markets, quotes,
#      18                                    get_instrument, reset_instrument)
#      20 """
#      21 for trading data
#      22 """
#      23 from tushare.stock.fundamental import (get_stock_basics, get_report_data,
#      24                                        get_profit_data,
#      25                                        get_operation_data, get_growth_data,
#      26                                        get_debtpaying_data, get_cashflow_data,
#      27                                        get_balance_sheet, get_profit_statement, get_cash_flow)
#
# File g:\a_stock_sentiment_system\.venv\Lib\site-packages\tushare\stock\trading.py:15
#      13 import lxml.html
#      14 from lxml import etree
# ---> 15 import pandas as pd
#      16 import numpy as np
#      17 import datetime
#
# File g:\a_stock_sentiment_system\.venv\Lib\site-packages\pandas\__init__.py:58
#      55 # let init-time option registration happen
#      56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#      61     Int8Dtype,
#      62     Int16Dtype,
#      63     Int32Dtype,
#      64     Int64Dtype,
#      65     UInt8Dtype,
#      66     UInt16Dtype,
#      67     UInt32Dtype,
#      68     UInt64Dtype,
#      69     Float32Dtype,
#      70     Float64Dtype,
#      71     CategoricalDtype,
#      72     PeriodDtype,
#      73     IntervalDtype,
#      74     DatetimeTZDtype,
#      75     StringDtype,
#      76     BooleanDtype,
#      77     # missing
#      78     NA,
#      79     isna,
#      80     isnull,
#      81     notna,
#      82     notnull,
#      83     # indexes
#      84     Index,
#      85     CategoricalIndex,
#      86     RangeIndex,
#      87     MultiIndex,
#      88     IntervalIndex,
#      89     TimedeltaIndex,
#      90     DatetimeIndex,
#      91     PeriodIndex,
#      92     IndexSlice,
#      93     # tseries
#      94     NaT,
#      95     Period,
#      96     period_range,
#      97     Timedelta,
#      98     timedelta_range,
#      99     Timestamp,
#     100     date_range,
#     101     bdate_range,
#     102     Interval,
#     103     interval_range,
#     104     DateOffset,
#     105     # conversion
#     106     to_numeric,
#     107     to_datetime,
#     108     to_timedelta,
#     109     # misc
#     110     Flags,
#     111     Grouper,
#     112     factorize,
#     113     unique,
#     114     NamedAgg,
#     115     array,
#     116     Categorical,
#     117     set_eng_float_format,
#     118     Series,
#     119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#     123 from pandas.core.dtypes.dtypes import SparseDtype
#
# File g:\a_stock_sentiment_system\.venv\Lib\site-packages\pandas\core\api.py:27
#      16 from pandas.core.dtypes.missing import (
#      17     isna,
#      18     isnull,
#      19     notna,
#      20     notnull,
#      21 )
#      23 from pandas.core.algorithms import (
#      24     factorize,
#      25     unique,
#      26 )
# ---> 27 from pandas.core.arrays import Categorical
#      28 from pandas.core.arrays.boolean import BooleanDtype
#      29 from pandas.core.arrays.floating import (
#      30     Float32Dtype,
#      31     Float64Dtype,
#      32 )
#
# File g:\a_stock_sentiment_system\.venv\Lib\site-packages\pandas\core\arrays\__init__.py:9
#       7 from pandas.core.arrays.boolean import BooleanArray
#       8 from pandas.core.arrays.categorical import Categorical
# ----> 9 from pandas.core.arrays.datetimes import DatetimeArray
#      10 from pandas.core.arrays.floating import FloatingArray
#      11 from pandas.core.arrays.integer import IntegerArray
#
# File g:\a_stock_sentiment_system\.venv\Lib\site-packages\pandas\core\arrays\datetimes.py:22
#      19 from pandas._config import using_string_dtype
#      20 from pandas._config.config import get_option
# ---> 22 from pandas._libs import (
#      23     lib,
#      24     tslib,
#      25 )
#      26 from pandas._libs.tslibs import (
#      27     BaseOffset,
#      28     NaT,
#    (...)     45     tzconversion,
#      46 )
#      47 from pandas._libs.tslibs.dtypes import abbrev_to_npy_unit
#
# File pandas/_libs/tslib.pyx:114, in init pandas._libs.tslib()
#
# SystemError: <class 'pandas._libs.tslib.__pyx_defaults'> returned a result with an exception set

# %%
import akshare as ak

stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20260403", end_date='20260403', adjust="qfq")
print(stock_zh_a_hist_df)
# Out:
#            日期    股票代码     开盘     收盘     最高     最低     成交量           成交额    振幅  \
# 0  2026-04-03  000001  11.28  11.12  11.28  11.09  757757  8.452836e+08  1.69
#
#     涨跌幅   涨跌额   换手率
# 0 -1.33 -0.15  0.39

# %%
df = pro.dc_index(idx_type = '行业板块',trade_date = '20260324')
df.sort_values(by = 'pct_change',inplace = True)
df

# %%
import akshare as ak

df = ak.stock_zt_pool_em('20260323')
df
