# %%
import tushare as ts
pro = ts.pro_api('9cb1d6a7b3a5cabf27023a45b0996e1f8e0c1e2676228278aed56cc7')
# df = pro.limit_list_d(trade_date='20260323', limit_type='U')
df = pro.stk_auction_o( trade_date='20260417', ts_code='002580.SZ')
df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 pro = ts.pro_api('9cb1d6a7b3a5cabf27023a45b0996e1f8e0c1e2676228278aed56cc7')
#       3 # df = pro.limit_list_d(trade_date='20260323', limit_type='U')
# ----> 4 df = pro.stk_auction_o( trade_date='20260417', ts_code='002580.SZ')
#       5 df
#
# File g:\a_stock_sentiment_system\.venv\Lib\site-packages\tushare\pro\client.py:45, in DataApi.query(self, api_name, fields, **kwargs)
#      43 result = json.loads(res.text)
#      44 if result['code'] != 0:
# ---> 45     raise Exception(result['msg'])
#      46 data = result['data']
#      47 columns = data['fields']
#
# Exception: 抱歉，您没有接口访问权限，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。

# %%
import akshare as ak

stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20260403", end_date='20260403', adjust="qfq")
print(stock_zh_a_hist_df)
# Out:
#            日期    股票代码     开盘     收盘     最高     最低     成交量           成交额    振幅  \
# 0  2026-04-03  000001  11.28  11.12  11.28  11.09  757757  8.452836e+08  1.69
#
#     涨跌幅   涨跌额   换手率
# 0 -1.33 -0.15  0.39

# %%
df = pro.dc_index(idx_type = '行业板块',trade_date = '20260324')
df.sort_values(by = 'pct_change',inplace = True)
df

# %%
import akshare as ak

df = ak.stock_zt_pool_em('20260323')
df
